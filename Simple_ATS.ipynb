# %% [markdown]
# <a href="https://colab.research.google.com/github/ronk83952-cmd/General/blob/main/Simple_ATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fix environment conflicts and install library
# !pip uninstall -y torch-xla
# !pip install --upgrade typing-extensions pydantic
# !pip install simple-ats
# Out:
# WARNING: Skipping torch-xla as it is not installed.
# ...

# %%
from simple_ats import ATS

# Initialize the ATS object at the start
ats = ATS()

# %%
# Load resume and job description content
resume_content = """WORK EXPERIENCE DOCUMENT
Organized by Company  |  Skills & Education Summary
PART 1: WORK EXPERIENCE BY COMPANY
1.  Building Contractor — Westend Mall Foundation Project
Period: October 2010 – December 2010   |   Duration: 3 months
•	After schooling at Kisumu senior academy in 2010 June, I was then going with a contractor during building foundation of westend mall which was from October to December of 2010, where I was learning but also kept records of cement in store and materials used during this phase.
2.  Pramukh Cash and Carry Ltd
Period: January 2011 – August 2013   |   Duration: 2 years 8 months
Warehouse (Initial Posting)
•	I was offered job at pramukh cash and carry ltd in 2011 January where I was stationed at warehouse, I did just be there to get started to know products and count goods that came in and which were removed which was loaded to trucks for delivery to customers' orders depending on invoices made by the office.
Retail & Wholesale Branch (Town) — Stock, Operations & Systems
•	I was then transferred to retail and wholesale outlet in town of the same company which had a wholesale and retail branch, where I was under the director and manager who was the same person in office and I was checking receipts for the goods billed at teller as per receipts for customers who were at teller.
•	For goods which came from warehouse in company trucks, I checked against invoice if quantity was right and also did checks with stocks as end of each day for fast moving goods daily and on Saturdays and Sundays we did other items check to ensure that stock was matched with the POS system, I worked with another team member to count and write a daily stock card.
•	Ensured that goods expires were checked, and if near expiry I had to tell the manager who was director and manager as well which we then discussed and made promotions structured in system to it was setup so it gets sold together.
•	Also had certain suppliers of goods, who would send goods to branch which I did check goods as per invoices.
•	After few months I also started to input invoices of goods received into the POS system, also daily at end of day I did backup of the system at managers office.
•	For till counter, I used to confirm daily sales amount which got calculated in the system and cash given to manager daily to confirm the amount matches the POS system amount daily.
•	I used to open the branch daily, I checked daily goods stocks so them I would call warehouse to give order so they bring goods from warehouse to the branch.
•	I looked after computers which I checked on network of computers as local network so teller machines are always connected to server in manager's office, also worked with another office guy to get office supplies list made so it can be ordered.
•	I also studied CCNA course which is computer networking certificate course at evening at Maseno University in Kisumu which was in 2 certificates as first was in 2012 and other in 2013 as each was 3 months long.
•	There was a time where the POS system crashed as main server had the OS system not functional and that time we had to do all things manual for writing receipts, make manual ETR tax receipt, and on the first day night the company got a POS system guy to install at evening and where it was me with this guy as well where we formatted the OS system and installed and setup OS system then the guy did POS system installed and configured to work, so during this time it was done at evening and night time so I was with him until 2am as after previous day we did sales as branch closed at 6pm and also had dinner we had together, while doing OS setup.
•	Since the system crashed was workday so on that weekend we organized weekend on Sunday full as stock taking day so we took stock for each SKU, and I entered all items along with manager to have the system to be updated with correct stocks.
•	I had a store key where high valued goods were locked in store where I used to manage the store myself only where I was in charge of having the stocks, maintain records for goods in and out as we did manual stock card entry and stocks fully in the system for this separate stock which I had the key.
•	I Interacted with customers, where prices was an issue as others as they complained that other shops sold cheaper prices so then I look at costing and adjust pricing for wholesale buyers and regular customers, as I checked whole sale prices of full and half units for wholesale vs. retail units sold as single units.
•	I managed pricing in the system with warehouse and branch sales pricing and margins, also reported to manager for complaints and solutions that customers complains.
•	On major incidences caught the goods which were stolen along with the guard which was involved, so I informed the manager who then took the action and I was in charge of checking CCTV. For casual workers hired daily caught them taking items under their clothing.
New Supermarket Branch (2013 Opening) — Setup & Operations
•	In 2013 a new branch was opened, so before the opening I made the master product file which in excel with barcode for each product as it was a supermarket, priced for each item.
•	In the POS system setup margins and entered all purchase invoices into the system.
•	After opening of the branch since it was supermarket we opened at 7am and we closed at 8pm daily, also received well in this branch which I was transferred before opening the branch.
•	Also at times when manager was off on weekends it was me maintaining all cash and system and also full branch I looked after on weekends.
•	All of this work at first branch I worked daily including Sundays as half day and for when transferred also all Sundays were full days only 1 Sunday off per month.
•	In retail and wholesale branch in town it had staff of 13 which I managed, and the supermarket had 28 in total. Customers were happy by my service.
3.  Study Period — India (HTML/CSS Web Development Course)
Period: September 2013 – April 2014   |   Duration: Approx. 8 months
•	Then went to India and did html css coding course for making websites in India as stay was until April 2014.
4.  Jubilee Jumbo Hardware Limited
Period: May 2014 – September 2014   |   Duration: 5 months (Temporary)
•	In May 2015 after coming back from India I got temporary work in Jubilee Jumbo hardware limited, I worked in hardware to expand myself in different field of works, which I also did handle customers and counter sales, did loading and offloading of goods.
•	Daily maintained records of workers and holiday schedules for staff on Sundays.
•	This then ended in sept 2014, it was 5 months duration.
5.  Jual Wholesalers Ltd
Period: October 2014 – June 2021   |   Duration: 6 years 8 months
Counter Sales & Operations (Oct 2014 – Jan 2015)
•	In Oct 2014, I started working at jual wholesaler's ltd, which I then worked as counter sales for first 3 months, also did load and offload goods, this time the system was manual writing of receipts then manual ETR tax receipt had to make for each sale.
IT Setup, POS/ERP Systems & Store Management (Feb 2015 onwards)
•	In feb 2015, proposed a system which was them purchased and I was part of the team and head as I was the one in charge of all IT things being implemented - all the computers and POS system setup and configured.
•	This new POS system was used for invoices making and other was for cash sales receipts while accounting was still carried on by the Quickbooks at the time.
•	I did make invoices, made cash sales at times when needed. I was in charge of maintaining the system working, I did backup and maintaining computer network.
•	I did was doing loading and offloading of goods as counting and verifying as per invoices. Then company got more trucks for sales delivery.
•	I was then added a store of high value goods which were high priced as well so I maintained stock and removed goods as per orders and delivery notes so I did have this locked and key with me during working days.
•	I also use to write delivery notes, and fuel loading note so listed truck can be loaded with fuel loaded as per route. I also managed routes so I made invoices for all customers for delivery in that route planned. For fuel delivery note we had assigned a petrol station so they would fuel the trucks with instructions as per delivery note of fuel.
•	Later company changed the POS system to erp system, which I was also handling as the same IT person. Also then company expanded to 2 more full stores which I was assigned to handle the opening and closing and maintain of the goods in those stores.
SC Johnson & Johnson Kenya Limited — Main Distributorship (Western & Nyanza Region)
•	As this was wholesaler and distributor of 14 companies as main distributor of beta healthcare and other few as sub distributors. Later the company got main western and nyanza region distributorship, where then I was handling all reporting to the company which was SC Johnson and Johnson Kenya limited.
•	For this SC johnson and johnson kenya limited, i maintained all stocks for this company as I was in charge. I did check stocks and made reports of sales, ordered goods needed and also made LPOs.
•	Designed promotions to customers along with regional sales manager.
•	Had a team of salespersons assigned to our distributorship so I managed them in terms of each having their own regions so they would get orders for those regions and share with me which then I processed to make invoices and have them loaded as per route plan I made and delivery and then later follow up on payments as well.
•	I also managed merchandisers to be in different outlets and how many staff needed and during season sales like back to school.
•	I did make invoices for customers, credit notes, and sometimes I helped in entering the purchases invoices into the system when accountant requested.
•	I maintained expired goods which were placed in different storage store then had it sorted by skus and company wise so could have them returned to company faster without delays as they were returns from customers as damages.
•	I did make email server and email accounts for all company staff, for emails from the customers I did respond and also followed up via emails and phone calls for payments and issues resolutions.
•	For payments I followed up I consulted the accountant so there was no errors when ending statements and asking for payment from the customers such any issues with the customers accounts or misallocated funds.
•	At the start the company used ERP system as it got for invoicing, cash sales as of main accounting was done QuickBooks, then later moved to ERP system for all accounting so then purchases invoices and all records started to be entered into the ERP system.
•	I also checked the shop, store for cleaning and goods arrangements as they are not misplaced and movement of goods kept in order of old goods removed fast so no expiries and old stocks as they say like first in first out rule.
•	I used call customers for orders, following up payments and this maintained good relationship with customers.
•	For purchase orders, I was calling and emailing the suppliers for goods needed, I did this for main distributorship of SC johnson and johnson kenya limited, but other companies goods I did also order but I wasn't major in that as the director used to order majorly so I would consult and I then ordered.
•	For SC Johnson and johnson kenya limited, I teamed up with this companies regional sales manager to create promotions for customers. From sc johnson and johnson kenya limited we had purchases discount in percentage and rebate discount as additional but as quarterly, so this made us archive targets of 70 million plus quarterly and for this I used to track our customers rebate targets as well as our companies as also customers for achieved rebate target would get rebate notes and this were many customers as regions served were nyanza and western and rift valley as our distributorship.
•	For our company I made promotions for cash purchaser for customers where it increases cash flow by them paying upon delivery as this helped our company get cash flow and cash rotation.
•	I reconciled stock for salespersons, stocks sold and pending in their trucks and payments brought from route salespersons which they went to sale on the route they planned for specific days of the week.
•	Here the drivers would get their orders from those customers he knows for his route, and rest we add goods to fill up the truck and when returned we then check stocks given minus the sold ones and returned the rest and check if the sales of stocks given match after returned goods to the company after sales on route.
•	As I worked in this company as main distributorship was sc johnson and johnson kenya limited, we had others like canon Chemicals Company and beta healthcare company and Afia products and Highlands company as others as main distributorship.
•	For these distributorships given to our company I worked along with regional sales managers and sales persons to reach customers to get orders and process orders, plan route for delivery, then have it loaded up in truck, after that on due dates follow up on payments.
•	Also haco industries limited also distributor, as we supplied to all shops as wholesalers supermarkets and small scale businesses in western and nyanza regions and rift valley and parts of Nairobi and nakuru regions as well.
•	So basically this was fast moving goods selling company with distributorships, as Haco industries as it had cosmetics, Afia was for food items and highlands for juices drinks, OTC medicines by beta healthcare and gsk company got specific products which are fast moving which was also products for Over the counter goods, back to school products and distributor of Twiga stationeries limited which dealt in schooling products and main as exercise books and stationeries. Eveready east Africa products as Eveready batteries.
•	Also managed workers as permanent whom had weekly pay and casuals did hire when needed. Here the shop staff was 11 permanent staff, and sales persons were 14 and merchandisers 20.
•	Increased total revenue of sales by 28% by reaching to more areas in same regions.
•	Improved delivery to be quicker as waiting days cut to few days so I did process orders fast.
•	I met sales targets for sc johnson and surpassed by 20 - 40% quarterly.
•	I introduced vehicle trackers to be installed so could monitor vehicles on road and deliveries was faster as time wasted in many short stops reduced.
•	Customers I served and maintained good relation which made them happy.
•	I was also looking at office supplies costings and had it reduced costings by 35% by direct purchasing as building relations with new supplier companies.
•	All this for this company worked until 2021 June, then left working there.
6.  Galaiya Stores
Period: November 2021 – February 2022   |   Duration: 4 months (Temporary — Owner Travelling)
•	In nov 2021 to feb 2022 named galaiya stores, I got offer to help out as paid managing the store of a retail shop. It major product was textile and clothes like plasticware as they did wholesale for textile. this was temporary as owner was travelling out of country.
•	I did serve customers, made manual receipts, made daily Z-reports for the end of day. cash deposit to bank. received goods from suppliers. sent purchase orders as needed. opened and closed the shop and also oversaw another store at different location.
•	Maintained staff attendance and their weekly pay. Had a staff of 7. Customers were happy by my service.
7.  Purve Sales (Ahero Town)
Period: November 2025 – December 2025   |   Duration: 2 months (Temporary)
•	In nov 2025 to dec 2025, started in Purve Sales located in ahero town. A hardware shop that also was on temporary basis. dealing in hardware items and metals as well as cement stockist.
•	Served customers, made receipts, checked stocks and gave purchase orders.
•	I checked goods for which customers bought, loaded orders for delivery in trucks of customers as well as for route delivery for the company truck to delivery to its customers.
•	I offloaded goods as receiving them to the shop. I checked pricing for each sku in the shop.
•	Daily morning hired casuals for the day that would work and their daily payments of day to day. Had staff of 8.
•	Improved goods delivery. orders dispatch. timely offloading. Made customers happy.
•	Introduced new process for goods dispatch and verification such as double checking processes for the goods before they left premises and handed to customers as this cut complaints of wrong goods given out and also at times costly given where as it was meant to be of different quality. This is end of this experience.


PART 2: CV SUMMARY — SKILLS, EXPERIENCE & EDUCATION
Written in plain, clear English based on all work history above.
Experience
Jual Wholesalers Ltd  —  October 2014 to June 2021  (6 years 8 months)
•	Ran day-to-day operations for a large wholesale and distribution company covering Western, Nyanza, and Rift Valley regions.
•	Managed stock, invoices, delivery routes, and payments for 14 product companies including SC Johnson & Johnson Kenya, Haco Industries, Beta Healthcare, Canon Chemicals, Afia, Highlands, Eveready, Twiga Stationeries, and others.
•	Led the set up and running of POS and ERP computer systems for the whole company.
•	Managed a team of 45 people — 11 shop staff, 14 sales persons, and 20 merchandisers.
•	Grew total sales revenue by 28% by reaching more areas in the same regions.
•	Met and exceeded SC Johnson quarterly sales targets by 20–40% and helped the company hit KES 70 million+ in quarterly sales.
•	Reduced office supply costs by 35% by building direct relationships with new suppliers.
•	Set up email server and email accounts for all company staff.
•	Introduced vehicle tracking system to improve delivery speed and reduce delays.
Pramukh Cash and Carry Ltd  —  January 2011 to August 2013  (2 years 8 months)
•	Worked in warehouse, retail, and wholesale operations at two branches.
•	Managed daily stock checks, POS system entries, cash reconciliation, and supplier invoice processing.
•	Led the full setup of a new supermarket branch before opening — built the product file with barcodes and pricing for all SKUs, and set up the POS system.
•	Managed a team of 13 staff at the retail/wholesale branch and 28 staff at the supermarket.
•	Handled loss prevention — caught theft incidents involving staff and a security guard, monitored CCTV.
•	Managed computer network (LAN), system backups, and supported OS and POS reinstallation during system crash.
Galaiya Stores  —  November 2021 to February 2022  (4 months, Temporary)
•	Fully managed a retail textile and plasticware shop while the owner was abroad.
•	Handled daily sales, cash handling, bank deposits, stock receiving, purchase orders, staff pay, and oversaw a second store location.
Purve Sales (Ahero)  —  November 2025 to December 2025  (2 months, Temporary)
•	Managed counter sales, stock, and goods dispatch at a hardware and cement shop.
•	Introduced a double-check process for outgoing goods that cut customer complaints about wrong or wrong-quality items.
Jubilee Jumbo Hardware Limited  —  May 2014 to September 2014  (5 months, Temporary)
•	Handled counter sales, customer service, loading and offloading of goods, and staff schedule records.
Westend Mall — Building Contractor  —  October 2010 to December 2010  (3 months)
•	Kept records of cement stock and materials used during the foundation phase of the building project.
Skills
Operations & Stock Management
•	Stock control, stock reconciliation, and stock taking (physical counts vs system)
•	First-in-first-out (FIFO) stock management and expiry management
•	Store management including locked high-value stock rooms
•	Goods receiving, verification against invoices, and loading/offloading
•	Purchase order (LPO) creation and supplier communication
Sales, Distribution & Customer Service
•	Route planning for delivery trucks and managing salesperson territories
•	Invoice and credit note processing; cash sales and counter sales
•	Customer relationship management, complaint handling, and payment follow-up
•	Designing and running trade promotions to increase sales and cash flow
•	Rebate target tracking and reporting for principal companies
•	Managing merchandiser teams in multiple retail outlets
IT & Systems
•	POS system setup, configuration, daily operation, and troubleshooting
•	ERP system implementation and daily use for invoicing, stock, and accounting
•	QuickBooks accounting support
•	Computer network (LAN) setup and maintenance
•	Email server setup and management
•	System backups, OS reinstallation, hardware and software troubleshooting
•	Microsoft Excel — product master files, pricing, and data records
•	Vehicle tracking system management
•	CCTV monitoring and loss prevention
•	HTML and CSS (basic website building)
People & Administration
•	Managing teams of up to 45 people — permanent staff, salespeople, and casual workers
•	Staff attendance, scheduling, and weekly pay management
•	Office supply procurement and cost management (achieved 35% cost reduction)
•	Daily reporting, Z-reports, and cash reconciliation
•	Bank deposits and cash handling
Education & Training
Secondary School
•	Kisumu Senior Academy — Completed June 2010
CCNA — Computer Networking Certificates
•	Maseno University, Kisumu — 2012 (Certificate 1) and 2013 (Certificate 2)
•	Each certificate was 3 months long. Covers computer networking fundamentals and local area network setup.
HTML & CSS — Website Development Course
•	Completed in India — September 2013 to April 2014
•	Covers building basic websites using HTML and CSS.
"""
jd_content = """Description

The Warehouse Manager is responsible for overseeing the efficient operation of the warehouse and logistics functions at IEA K. This role includes managing inventory, coordinating the distribution and receipt of shipments, optimizing warehouse processes, and ensuring compliance with safety standards.

Experience


    Minimum of 5 years’ experience in warehouse management, logistics, or supply chain operations, with at least 2 years in a supervisory or managerial role.


    Strong working knowledge of warehouse operations, inventory control, order fulfillment, reverse logistics, and distribution processes.


    Proven experience working with inventory management systems (WMS / ERP) and enforcing system and process compliance


    Demonstrated ability to lead teams, manage performance, and drive operational improvements.



Qualifications


    Bachelor’s degree in supply chain management, Logistics, Business Administration, or a related field.


    Professional certifications in logistics, supply chain, or operations management (e.g. CIPS, APICS, or equivalent) will be an added advantage.




Responsibilities

Warehouse Operations & Planning


    Oversee daily warehouse operations including receiving, storage, inventory handling, order fulfilment, and reverse logistics in collaboration with internal and external stakeholder ·


    Plan and manage warehouse capacity, space utilization, layout optimization, and material flows to support business requirements.


    Ensure efficient allocation of labour, equipment, and resources to meet operational targets.


    Support continuous alignment between warehouse operations and overall company objectives.



Inventory Control & Accuracy


    Own end-to-end inventory control, always ensuring high inventory accuracy and integrity.


    Monitor stock levels, conduct cycle counts and periodic physical stock counts, and reconcile variances.


    Investigate inventory discrepancies, damages, losses, and obsolete stock, and implement corrective and preventive actions.


    Ensure proper handling, segregation, and tracking of serialized, bulk, returned, and reverse- logistics items.


    Implement double-verification before dispatch.


    Ensure serialized device traceability



Inventory Management Systems & Data


    Ensure real-time, accurate recording of all inventory movements and enforce full system-usage compliance.


    Ensure 100% on-time reporting of inventory and warehouse data in the company’s systems.


    Prepare and present daily, weekly, and monthly warehouse performance reports and dashboards.


    Use data and KPIs to drive operational decisions and continuous improvement.



Cost, Risk & Audit Management


    Develop, implement, and maintain warehouse SOPs, policies, and process documentation.


    Drive continuous improvement initiatives (e.g. Lean, 5S, process optimization) to improve efficiency, accuracy, and cost control.


    Support warehouse budgeting and cost monitoring


    Identify operational risks and implement mitigation and corrective actions.


    Prepare and present daily, weekly and monthly reports on warehouse performance and relevant KPIs



People Management & Leadership·


    Lead, motivate, and develop warehouse staff to foster a positive, productive, and safety-focused work environment.


    Set performance goals, conduct regular evaluations, and provide coaching, training, and skills development.


    Plan staffing levels, shifts, overtime, and productivity targets in line with operational needs.


    Manage performance issues, disciplinary processes, and succession planning where required.



"""

# %%
# Load the resume content
ats.load_resume(resume_content)

# %%
# Load the job description content
ats.load_job_description(jd_content)

# %%
# Extract and clean experience
experience = ats.extract_experience()
ats.clean_experience(experience)

# Extract and clean skills
skills = " ".join(ats.extract_skills())
ats.clean_skills(skills)

# Compute and print the similarity score
similarity_score = ats.compute_similarity()
print(f"The similarity score between the resume and job description is: {round(similarity_score.item() * 100, 2)}%")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# ...

# %%
# Final summary of the analysis
try:
    print(f'Final Similarity Score: {round(similarity_score.item() * 100, 2)}%')
except NameError:
    print('Analysis is still in progress or needs to be re-run.')
# Out:
# Final Similarity Score: 61.44%
